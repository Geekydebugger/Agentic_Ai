# %% [markdown]
# <a href="https://colab.research.google.com/github/Geekydebugger/Agentic_Ai/blob/main/Agentic_Ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
print(userdata.get('GROQ_API_KEY')[:10] + '...')
print(userdata.get('GOOGLE_API_KEY')[:10] + '...')
print(userdata.get('HF_TOKEN')[:10] + '...')
# Out:
# gsk_n2k220...
# AIzaSyCV55...
# hf_LGnykNU...
